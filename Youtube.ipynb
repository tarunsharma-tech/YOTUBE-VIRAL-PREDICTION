# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Global YouTube Statistics.csv',encoding='latin1')

# %%
df.head(3)
# Out:
#    rank        Youtuber  subscribers   video views          category  \
# 0     1        T-Series    245000000  2.280000e+11             Music
# 1     2  YouTube Movies    170000000  0.000000e+00  Film & Animation
# 2     3         MrBeast    166000000  2.836884e+10     Entertainment
#
#            Title  uploads        Country Abbreviation   channel_type  ...  \
# 0       T-Series    20082          India           IN          Music  ...
# 1  youtubemovies        1  United States           US          Games  ...
# 2        MrBeast      741  United States           US  Entertainment  ...
#
#    subscribers_for_last_30_days  created_year  created_month  created_date  \
# 0                     2000000.0        2006.0            Mar          13.0
# 1                           NaN        2006.0            Mar           5.0
# 2                     8000000.0        2012.0            Feb          20.0
#
#    Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# ...

# %%
df.shape
# Out:
# (995, 28)

# %%
df.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
df['video_views_for_the_last_30_days' ].fillna(df['video_views_for_the_last_30_days' ].mean)
# Out:
# 0      2258000000.0
# 1              12.0
# 2      1348000000.0
# 3      1975000000.0
# 4      1824000000.0
#            ...
# 990     552513000.0
# 991      64735000.0
# 992         67035.0
# 993       3871000.0
# 994      24000000.0
# Name: video_views_for_the_last_30_days, Length: 995, dtype: object

# %%
df['video_views_for_the_last_30_days' ].isna().sum()
# Out:
# np.int64(56)

# %%
df.sort_values(by='subscribers', ascending=False).head(10)
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
# 5     6                       Music    119000000  0.000000e+00
# 6     7         ýýý Kids Diana Show    112000000  9.324704e+10
# 7     8                   PewDiePie    111000000  2.905804e+10
# 8     9                 Like Nastya    106000000  9.047906e+10
# 9    10               Vlad and Niki     98900000  7.718017e+10
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# ...

# %%
df['category'].value_counts()
# Out:
# category
# Entertainment            241
# Music                    202
# People & Blogs           132
# Gaming                    94
# Comedy                    69
# Film & Animation          46
# Education                 45
# Howto & Style             40
# News & Politics           26
# Science & Technology      17
# Shows                     13
# Sports                    11
# Pets & Animals             4
# Trailers                   2
# Nonprofits & Activism      2
# Movies                     2
# Autos & Vehicles           2
# Travel & Events            1
# Name: count, dtype: int64

# %%
df.groupby('category')['subscribers'].mean()
# Out:
# category
# Autos & Vehicles         1.785000e+07
# Comedy                   2.012319e+07
# Education                2.654222e+07
# Entertainment            2.140332e+07
# Film & Animation         2.858478e+07
# Gaming                   2.085213e+07
# Howto & Style            1.939000e+07
# Movies                   2.565000e+07
# Music                    2.571782e+07
# News & Politics          2.063077e+07
# Nonprofits & Activism    2.775000e+07
# People & Blogs           2.105606e+07
# Pets & Animals           1.810000e+07
# Science & Technology     1.861765e+07
# Shows                    4.161538e+07
# Sports                   2.710909e+07
# Trailers                 3.900000e+07
# Travel & Events          1.250000e+07
# Name: subscribers, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States           313
# India                   168
# Brazil                   62
# United Kingdom           43
# Mexico                   33
# Indonesia                28
# Spain                    22
# Thailand                 18
# South Korea              17
# Russia                   16
# Canada                   15
# Argentina                13
# Philippines              12
# Colombia                 11
# Saudi Arabia              9
# Australia                 9
# Ukraine                   8
# United Arab Emirates      7
# Pakistan                  6
# Germany                   6
# France                    5
# Japan                     5
# Turkey                    4
# Sweden                    4
# Chile                     3
# Jordan                    3
# Netherlands               3
# Vietnam                   3
# Singapore                 3
# Ecuador                   2
# Egypt                     2
# Iraq                      2
# Italy                     2
# ...

# %%
df.sort_values(by='highest_yearly_earnings', ascending=False).head(10)
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 495   496            ýýýýýýýýý KIMPRO     17700000  1.920670e+10
# 417   418                DaFuq!?Boom!     19600000  7.906182e+09
# 0       1                    T-Series    245000000  2.280000e+11
# 302   303         KL BRO Biju Rithvik     22800000  1.798835e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# 21     22                      Zee TV     70500000  7.313905e+10
# 139   140                    StarPlus     32000000  2.680067e+10
# 15     16                    Sony SAB     83000000  1.010000e+11
# 83     84                 GR6 EXPLODE     38900000  2.515423e+10
#
#              category                       Title  uploads        Country  \
# 495               NaN            ýýýýýýýýý KIMPRO     1646    South Korea
# 417  Film & Animation                DaFuq!?Boom!      214  United States
# ...

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(y='uploads',x='subscribers',data = df)
# Out:
# <Axes: xlabel='subscribers', ylabel='uploads'>

# %%
top_earn_cat = df.groupby('category')['highest_yearly_earnings'].sum().sort_values(ascending = False)

# %%
plt.figure(figsize=(14,6))
plt.xticks(rotation=45, ha='right')
sns.barplot(
    x=top_earn_cat.index
            ,y=top_earn_cat.values
            ,
            errorbar=None)
# Out:
# <Axes: xlabel='category'>

# %%
top_views = df.groupby('Country')['video views'].sum().sort_values(ascending = False).head(10)

# %%
top_views
# Out:
# Country
# United States     3.690292e+12
# India             2.281048e+12
# Brazil            4.812090e+11
# United Kingdom    4.305665e+11
# Thailand          2.643180e+11
# Russia            2.329963e+11
# South Korea       2.255917e+11
# Mexico            1.982199e+11
# Argentina         1.944154e+11
# Canada            1.913206e+11
# Name: video views, dtype: float64

# %%
plt.figure(figsize=(14,6))
plt.xticks(rotation=45, ha='right')
sns.barplot(
    x=top_views.index
            ,y=top_views.values
            ,
            errorbar=None)
# Out:
# <Axes: xlabel='Country'>

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.groupby('channel_type')[
    'subscribers_for_last_30_days'
].mean().sort_values(ascending = False)
# Out:
# channel_type
# Animals          766666.666667
# People           496902.968254
# Sports           490000.100000
# Entertainment    449466.570732
# Comedy           439397.030303
# Film             320618.558824
# Education        297500.000000
# Games            296776.966667
# News             270384.615385
# Nonprofit        250000.000000
# Howto            237500.000000
# Tech             228571.428571
# Music            212576.632353
# Autos            166670.333333
# Name: subscribers_for_last_30_days, dtype: float64

# %%
df['channel_age'] = 2026 - df['created_year']

# %%
df['channel_age'].head(4)
# Out:
# 0    20.0
# 1    20.0
# 2    14.0
# 3    20.0
# Name: channel_age, dtype: float64

# %%
df.groupby('Youtuber')[
    'channel_age'
].sum().sort_values(ascending = False).head(50)
# Out:
# Youtuber
# YouTube                            56.0
# Rihanna                            21.0
# Apple                              21.0
# Smosh                              21.0
# BBC                                21.0
# PlayStation                        21.0
# Ishtar Music                       21.0
# Crazy Frog                         21.0
# VICE                               21.0
# CKN                                21.0
# Beyoncï¿                           21.0
# CNN                                21.0
# Jennifer Lopez                     21.0
# NBA                                21.0
# Bad Bunny                          21.0
# Michael Jackson                    21.0
# Avril Lavigne                      21.0
# BIGBANG                            21.0
# Shakira                            21.0
# Drake                              21.0
# Zee TV                             21.0
# LEGO                               21.0
# BRIGHT SIDE                        21.0
# ...

# %%
sns.scatterplot(
    x='channel_age',
    y='subscribers',
    data=df
)
# Out:
# <Axes: xlabel='channel_age', ylabel='subscribers'>

# %%
df['views_per_upload'] = df['video views']/ df['uploads']

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude',
#        'channel_age', 'views_per_upload'],
#       dtype='object')

# %%
df.groupby('Youtuber')['video views'].mean().sort_values(ascending= False).head(10)
# Out:
# Youtuber
# T-Series                      2.280000e+11
# Cocomelon - Nursery Rhymes    1.640000e+11
# SET India                     1.480000e+11
# Sony SAB                      1.010000e+11
# ýýý Kids Diana Show           9.324704e+10
# Like Nastya                   9.047906e+10
# WWE                           7.742847e+10
# Vlad and Niki                 7.718017e+10
# Zee TV                        7.313905e+10
# Colors TV                     6.151091e+10
# Name: video views, dtype: float64

# %%
df.groupby('Youtuber')['subscribers'].mean().sort_values(ascending= False).head(10)
# Out:
# Youtuber
# T-Series                      245000000.0
# YouTube Movies                170000000.0
# MrBeast                       166000000.0
# Cocomelon - Nursery Rhymes    162000000.0
# SET India                     159000000.0
# Music                         119000000.0
# ýýý Kids Diana Show           112000000.0
# PewDiePie                     111000000.0
# Like Nastya                   106000000.0
# Vlad and Niki                  98900000.0
# Name: subscribers, dtype: float64

# %%
top_co =df['Country'].value_counts().head(10)

# %%
df.groupby('Country')['subscribers'].mean().sort_values(ascending= False).head(10)
# Out:
# Country
# Cuba           4.630000e+07
# El Salvador    4.610000e+07
# Barbados       4.190000e+07
# Japan          3.782000e+07
# Venezuela      3.120000e+07
# Kuwait         3.050000e+07
# Chile          2.906667e+07
# South Korea    2.833529e+07
# Pakistan       2.590000e+07
# India          2.565833e+07
# Name: subscribers, dtype: float64

# %%
plt.xticks(rotation=45, ha='right')
sns.barplot(top_co)
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
df.groupby('category')['uploads'].mean().sort_values(ascending= False)
# Out:
# category
# News & Politics          112484.384615
# Nonprofits & Activism    102912.000000
# Shows                     27443.692308
# Sports                    14493.727273
# Entertainment             11908.481328
# People & Blogs             9190.780303
# Trailers                   6839.000000
# Pets & Animals             4451.500000
# Gaming                     4313.414894
# Movies                     3553.000000
# Education                  3142.866667
# Film & Animation           2799.652174
# Music                      2335.509901
# Science & Technology       2114.058824
# Autos & Vehicles           1898.500000
# Howto & Style              1673.350000
# Comedy                     1119.753623
# Travel & Events             766.000000
# Name: uploads, dtype: float64

# %%
df.groupby('category')['subscribers'].mean().sort_values(ascending= False)
# Out:
# category
# Shows                    4.161538e+07
# Trailers                 3.900000e+07
# Film & Animation         2.858478e+07
# Nonprofits & Activism    2.775000e+07
# Sports                   2.710909e+07
# Education                2.654222e+07
# Music                    2.571782e+07
# Movies                   2.565000e+07
# Entertainment            2.140332e+07
# People & Blogs           2.105606e+07
# Gaming                   2.085213e+07
# News & Politics          2.063077e+07
# Comedy                   2.012319e+07
# Howto & Style            1.939000e+07
# Science & Technology     1.861765e+07
# Pets & Animals           1.810000e+07
# Autos & Vehicles         1.785000e+07
# Travel & Events          1.250000e+07
# Name: subscribers, dtype: float64

# %%
high_uploads =df.groupby('Youtuber')['uploads'].max().sort_values(ascending= False)

# %%
low_subs =df.groupby('Youtuber')['subscribers'].min().sort_values(ascending= True)

# %%
so_me =( high_uploads & low_subs).min()

# %%
so_me
# Out:
# np.False_

# %%
high_uploads = df['uploads'] > df['uploads'].quantile(0.75)  # top 25% uploaders
low_subs = df['subscribers'] < df['subscribers'].quantile(0.25)  # bottom 25% subs

# %%
so_me =( high_uploads & low_subs)

# %%
so_me
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 990    False
# 991    False
# 992    False
# 993    False
# 994    False
# Length: 995, dtype: bool

# %%
high_uploads = df['uploads'].quantile(0.75)

low_subscribers = df['subscribers'].quantile(0.25)

result = df[
    (df['uploads'] > high_uploads) &
    (df['subscribers'] < low_subscribers)
]

result[['Youtuber', 'uploads', 'subscribers']]
# Out:
#                                           Youtuber  uploads  subscribers
# 753                                 Gyan Gamingï¿½     3086     14400000
# 764                                 RS 1313 SHORTS     5628     14400000
# 767                                           ZEE5   101401     14400000
# 780                                     Zee Bangla   132398     14200000
# 787                                 Yudist Ardhana     2854     14100000
# 792                                         AM3NlC     5757     14000000
# 798                                       ViralHog    41117     14000000
# 799                                 ETV Jabardasth     9652     14000000
# 802                                      Jazzghost     5494     13900000
# 806                              T-Series Regional    15075     13900000
# 818                                       Geo News   190093     13800000
# 820                              Think Music India     4978     13800000
# ...

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude',
#        'channel_age', 'views_per_upload'],
#       dtype='object')

# %%
plt.figure(figsize=(8,5))

sns.histplot(df['subscribers'], bins=30)

plt.title('Distribution of Subscribers')
# Out:
# Text(0.5, 1.0, 'Distribution of Subscribers')

# %%
plt.figure(figsize=(8,5))

sns.histplot(df['uploads'], bins=30)

plt.title('Distribution of uploads')
# Out:
# Text(0.5, 1.0, 'Distribution of uploads')

# %%
plt.figure(figsize=(8,5))

sns.histplot(df['highest_yearly_earnings'], bins=30)

plt.title('highest_yearly_earnings')
# Out:
# Text(0.5, 1.0, 'highest_yearly_earnings')

# %%
df['subscribers'].dtype
# Out:
# dtype('int64')

# %%
plt.figure(figsize=(10,8))
plt.xticks(rotation=45, ha='right')
sns.scatterplot(x ='video views' , y = 'subscribers' , data = df)
# Out:
# <Axes: xlabel='video views', ylabel='subscribers'>

# %%
num_col =[['subscribers', 'video views','uploads','video_views_rank','video_views_for_the_last_30_days', 'lowest_monthly_earnings',
       'highest_monthly_earnings', 'lowest_yearly_earnings',
       'highest_yearly_earnings', 'subscribers_for_last_30_days','Urban_population']]

# %%
plt.figure(figsize=(12,8))
plt.xticks(rotation=45, ha='right')
sns.heatmap(df.select_dtypes(include='number').corr(),annot=True,
            fmt='.2f',
            cmap='coolwarm',
            linewidths=0.5)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude',
#        'channel_age', 'views_per_upload'],
#       dtype='object')

# %%
df.drop(columns= ['lowest_monthly_earnings','highest_monthly_earnings','lowest_yearly_earnings'],inplace = True)

# %%
df.drop(columns=['Longitude', 'Latitude', 'Unemployment rate','Gross tertiary education enrollment (%)'], inplace=True)

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'highest_yearly_earnings',
#        'subscribers_for_last_30_days', 'created_year', 'created_month',
#        'created_date', 'Population', 'Urban_population', 'channel_age',
#        'views_per_upload'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

# %%
cols_to_scale = [col for col in df.select_dtypes(include='number').columns 
                 if df[col].nunique() > 2]

# %%
cols_to_scale
# Out:
# ['rank',
#  'subscribers',
#  'video views',
#  'uploads',
#  'video_views_rank',
#  'country_rank',
#  'channel_type_rank',
#  'video_views_for_the_last_30_days',
#  'highest_yearly_earnings',
#  'subscribers_for_last_30_days',
#  'created_year',
#  'created_date',
#  'Population',
#  'Urban_population',
#  'channel_age',
#  'views_per_upload']

# %%
df.head(2)
# Out:
#    rank        Youtuber  subscribers   video views          category  \
# 0     1        T-Series    245000000  2.280000e+11             Music
# 1     2  YouTube Movies    170000000  0.000000e+00  Film & Animation
#
#            Title  uploads        Country Abbreviation channel_type  ...  \
# 0       T-Series    20082          India           IN        Music  ...
# 1  youtubemovies        1  United States           US        Games  ...
#
#    video_views_for_the_last_30_days  highest_yearly_earnings  \
# 0                      2.258000e+09             1.084000e+08
# 1                      1.200000e+01             5.800000e-01
#
#    subscribers_for_last_30_days  created_year  created_month  created_date  \
# 0                     2000000.0        2006.0            Mar          13.0
# 1                           NaN        2006.0            Mar           5.0
#
#      Population Urban_population  channel_age  views_per_upload
# ...

# %%
plt.figure(figsize=(12,8))
plt.xticks(rotation=45, ha='right')
sns.heatmap(df.select_dtypes(include='number').corr(),annot=True,
            fmt='.2f',
            cmap='coolwarm',
            linewidths=0.5)
# Out:
# <Axes: >

# %%
df['subscribers_for_last_30_days'].median()
# Out:
# 200000.0

# %%
df['subscribers_for_last_30_days'].value_counts()
# Out:
# subscribers_for_last_30_days
# 100000.0     256
# 200000.0     104
# 300000.0      59
# 400000.0      39
# 500000.0      25
# 600000.0      24
# 700000.0      20
# 1.0           16
# 900000.0      11
# 1100000.0      9
# 800000.0       8
# 1000000.0      8
# 10.0           7
# 1300000.0      6
# 1600000.0      5
# 1200000.0      5
# 2.0            4
# 100.0          4
# 4.0            3
# 3.0            3
# 1900000.0      3
# 1000.0         3
# 5.0            2
# 3200000.0      2
# 2000000.0      2
# 8.0            2
# 3400000.0      2
# 8000000.0      1
# 75.0           1
# 2000.0         1
# 6.0            1
# 151.0          1
# 40000.0        1
# 1400000.0      1
# 12.0           1
# 2100000.0      1
# 5500000.0      1
# 6700000.0      1
# 30.0           1
# 230000.0       1
# 2960.0         1
# 11.0           1
# 800.0          1
# 9.0            1
# 3000000.0      1
# 3580.0         1
# 1700000.0      1
# 10000.0        1
# 600.0          1
# 132.0          1
# 130.0          1
# ...

# %%
df.head(10)
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
# 5     6                       Music    119000000  0.000000e+00
# 6     7         ýýý Kids Diana Show    112000000  9.324704e+10
# 7     8                   PewDiePie    111000000  2.905804e+10
# 8     9                 Like Nastya    106000000  9.047906e+10
# 9    10               Vlad and Niki     98900000  7.718017e+10
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# ...

# %%
df['viral_channel'] = (
    df['video_views_for_the_last_30_days']
    > df['video_views_for_the_last_30_days'].median()
).astype(int)

# %%
df.isin([np.inf, -np.inf]).sum()
# Out:
# rank                                 0
# Youtuber                             0
# subscribers                          0
# video views                          0
# category                             0
# Title                                0
# uploads                              0
# Country                              0
# Abbreviation                         0
# channel_type                         0
# video_views_rank                     0
# country_rank                         0
# channel_type_rank                    0
# video_views_for_the_last_30_days     0
# highest_yearly_earnings              0
# subscribers_for_last_30_days         0
# created_year                         0
# created_month                        0
# created_date                         0
# Population                           0
# Urban_population                     0
# channel_age                          0
# views_per_upload                    38
# viral_channel                        0
# dtype: int64

# %%
# Assistant
import numpy as np
from sklearn.preprocessing import RobustScaler

# Check for infinite values before scaling
print("Infinite values found:", np.isinf(df[cols_to_scale]).sum().sum())
print("Very large values found:", (np.abs(df[cols_to_scale]) > 1e10).sum().sum())

# Replace infinite values with NaN, then handle them
df[cols_to_scale] = df[cols_to_scale].replace([np.inf, -np.inf], np.nan)

# Option 1: Drop rows with NaN values
# df = df.dropna(subset=cols_to_scale)

# Option 2: Fill NaN values with median (recommended for RobustScaler)
df[cols_to_scale] = df[cols_to_scale].fillna(df[cols_to_scale].median())
# Out:
# Infinite values found: 38
# Very large values found: 416

# %%
encode = df.copy()

# %%
encode['Country'].value_counts()
# Out:
# Country
# United States           313
# India                   168
# Brazil                   62
# United Kingdom           43
# Mexico                   33
# Indonesia                28
# Spain                    22
# Thailand                 18
# South Korea              17
# Russia                   16
# Canada                   15
# Argentina                13
# Philippines              12
# Colombia                 11
# Saudi Arabia              9
# Australia                 9
# Ukraine                   8
# United Arab Emirates      7
# Pakistan                  6
# Germany                   6
# France                    5
# Japan                     5
# Turkey                    4
# Sweden                    4
# Chile                     3
# Jordan                    3
# Netherlands               3
# Vietnam                   3
# Singapore                 3
# Ecuador                   2
# Egypt                     2
# Iraq                      2
# Italy                     2
# ...

# %%
encode.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'highest_yearly_earnings',
#        'subscribers_for_last_30_days', 'created_year', 'created_month',
#        'created_date', 'Population', 'Urban_population', 'channel_age',
#        'views_per_upload', 'viral_channel'],
#       dtype='object')

# %%
encode.drop(['rank', 'Youtuber' ,'category' ,'Title','Abbreviation','video_views_rank', 'country_rank', 'channel_type_rank','created_month','created_date'] , axis = 1 , inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

country_encoder = LabelEncoder()
channel_encoder = LabelEncoder()

encode['Country'] = country_encoder.fit_transform(
    encode['Country']
)

encode['channel_type'] = channel_encoder.fit_transform(
    encode['channel_type']
)

# %%
encode.head()
# Out:
#    subscribers   video views  uploads  Country  channel_type  \
# 0    245000000  2.280000e+11    20082       18             8
# 1    170000000  0.000000e+00        1       46             6
# 2    166000000  2.836884e+10      741       46             4
# 3    162000000  1.640000e+11      966       46             3
# 4    159000000  1.480000e+11   116536       18             4
#
#    video_views_for_the_last_30_days  highest_yearly_earnings  \
# 0                      2.258000e+09             1.084000e+08
# 1                      1.200000e+01             5.800000e-01
# 2                      1.348000e+09             6.470000e+07
# 3                      1.975000e+09             9.480000e+07
# 4                      1.824000e+09             8.750000e+07
#
#    subscribers_for_last_30_days  created_year    Population  Urban_population  \
# 0                     2000000.0        2006.0  1.366418e+09       471031528.0
# ...

# %%
encode.corr(numeric_only=True)
# Out:
#                                   subscribers  video views   uploads  \
# subscribers                          1.000000     0.750958  0.077136
# video views                          0.750958     1.000000  0.165928
# uploads                              0.077136     0.165928  1.000000
# Country                              0.006151     0.003520 -0.090093
# channel_type                        -0.015517    -0.030372  0.031722
# video_views_for_the_last_30_days     0.269655     0.362882  0.105267
# highest_yearly_earnings              0.388935     0.552091  0.166904
# subscribers_for_last_30_days         0.270055     0.192514  0.027984
# created_year                        -0.141895    -0.127119 -0.154985
# Population                           0.076693     0.081297  0.149267
# Urban_population                     0.081201     0.070941  0.062066
# channel_age                          0.141895     0.127119  0.154985
# views_per_upload                     0.130103     0.081976 -0.047565
# ...

# %%
encode['viral_channel'].value_counts()
# Out:
# viral_channel
# 0    526
# 1    469
# Name: count, dtype: int64

# %%
df[cols_to_scale].columns
# Out:
# Index(['rank', 'subscribers', 'video views', 'uploads', 'video_views_rank',
#        'country_rank', 'channel_type_rank', 'video_views_for_the_last_30_days',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_date', 'Population', 'Urban_population',
#        'channel_age', 'views_per_upload'],
#       dtype='object')

# %%
encode.head(2)
# Out:
#    subscribers   video views  uploads  Country  channel_type  \
# 0    245000000  2.280000e+11    20082       18             8
# 1    170000000  0.000000e+00        1       46             6
#
#    video_views_for_the_last_30_days  highest_yearly_earnings  \
# 0                      2.258000e+09             1.084000e+08
# 1                      1.200000e+01             5.800000e-01
#
#    subscribers_for_last_30_days  created_year    Population  Urban_population  \
# 0                     2000000.0        2006.0  1.366418e+09       471031528.0
# 1                      200000.0        2006.0  3.282395e+08       270663028.0
#
#    channel_age  views_per_upload  viral_channel
# 0         20.0      1.135345e+07              1
# 1         20.0      0.000000e+00              0

# %%
encode.columns
# Out:
# Index(['subscribers', 'video views', 'uploads', 'Country', 'channel_type',
#        'video_views_for_the_last_30_days', 'highest_yearly_earnings',
#        'subscribers_for_last_30_days', 'created_year', 'Population',
#        'Urban_population', 'channel_age', 'views_per_upload', 'viral_channel'],
#       dtype='object')

# %%
encode['video views'] = encode['video views'].astype('int64')
encode['video_views_for_the_last_30_days'] = encode['video_views_for_the_last_30_days'].astype('int64')
encode['highest_yearly_earnings'] = encode['highest_yearly_earnings'].astype('int64')
encode['Population'] = encode['Population'].astype('int64')
encode['Urban_population'] = encode['Urban_population'].astype('int64')
encode['views_per_upload'] = encode['views_per_upload'].astype('int64')

# %%
encode.head(15)
# Out:
#     subscribers   video views  uploads  Country  channel_type  \
# 0     245000000  228000000000    20082       18             8
# 1     170000000             0        1       46             6
# 2     166000000   28368841870      741       46             4
# 3     162000000  164000000000      966       46             3
# 4     159000000  148000000000   116536       18             4
# 5     119000000             0        0       49             8
# 6     112000000   93247040539     1111       46             4
# 7     111000000   29058044447     4716       22             4
# 8     106000000   90479060027      493       33            11
# 9      98900000   77180169894      574       46             4
# 10     96700000   57856289381     8548       18             8
# 11     96000000   77428473662    70127       46            12
# 12     93600000             0        0       49             6
# 13     89800000   32144597566      543       37             8
# ...

# %%
encode['highest_yearly_earnings'].value_counts()
# Out:
# highest_yearly_earnings
# 0          119
# 1300000     21
# 2100000     17
# 1400000     15
# 1200000     13
#           ...
# 425700       1
# 66900        1
# 736300       1
# 407200       1
# 285700       1
# Name: count, Length: 405, dtype: int64

# %%
X = encode.drop(['viral_channel','video_views_for_the_last_30_days'] , axis = 1)

# %%
y= encode['viral_channel']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.23, random_state=42)

# %%
scaler = StandardScaler()
X_test_scaled = scaler.fit_transform(X_test)
X_train_scaled = scaler.fit_transform(X_train)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier 
from sklearn.metrics import classification_report , f1_score , accuracy_score,confusion_matrix

# %%
models = {
    'Logistic Regression' : LogisticRegression(class_weight= 'balanced'),
    'KNN' : KNeighborsClassifier(n_neighbors=7),
    'Naive Bayes' :GaussianNB(),
    'Decision Tree' : DecisionTreeClassifier(),
    'SVM' : SVC(probability=True),
    'Random forest' : RandomForestClassifier() 
}

# %%
result = []

# %%
for name,model in models.items():
    model.fit(X_train_scaled,y_train)
    y_pred = model.predict(X_test_scaled)
    Accuracy =accuracy_score(y_pred , y_test)
    F1 = f1_score(y_pred , y_test)
    Report = classification_report(y_pred , y_test)
    result.append(
        {'model': name,
        'Accuracy': round(Accuracy, 4),
        'F1': round(F1, 4)}
    )

# %%
result
# Out:
# [{'model': 'Logistic Regression', 'Accuracy': 0.8472, 'F1': 0.8341},
#  {'model': 'KNN', 'Accuracy': 0.7817, 'F1': 0.7619},
#  {'model': 'Naive Bayes', 'Accuracy': 0.8079, 'F1': 0.8254},
#  {'model': 'Decision Tree', 'Accuracy': 0.8428, 'F1': 0.8421},
#  {'model': 'SVM', 'Accuracy': 0.8122, 'F1': 0.7902},
#  {'model': 'Random forest', 'Accuracy': 0.8734, 'F1': 0.8664}]

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=200,
    random_state=42
)

rf.fit(X_train, y_train)

rf.feature_importances_
# Out:
# array([0.0190334 , 0.10076475, 0.047995  , 0.01154814, 0.00952483,
#        0.65135988, 0.11016883, 0.00844758, 0.00510105, 0.00533359,
#        0.00759317, 0.02312979])

# %%
feature_importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf.feature_importances_
})

feature_importance.sort_values(
    by="Importance",
    ascending=False
)
# Out:
#                          Feature  Importance
# 5        highest_yearly_earnings    0.651360
# 6   subscribers_for_last_30_days    0.110169
# 1                    video views    0.100765
# 2                        uploads    0.047995
# 11              views_per_upload    0.023130
# 0                    subscribers    0.019033
# 3                        Country    0.011548
# 4                   channel_type    0.009525
# 7                   created_year    0.008448
# 10                   channel_age    0.007593
# 9               Urban_population    0.005334
# 8                     Population    0.005101

# %% [markdown]
# This was model two after removiving some more feature so the data leakage reduced

# %%
X2 = encode.drop([
    'viral_channel',
    'video_views_for_the_last_30_days',
    'highest_yearly_earnings',
    'subscribers_for_last_30_days'
], axis=1)

# %%
y2 = encode['viral_channel']

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.23, random_state=42)

# %%
X2_test_scaled = scaler.fit_transform(X2_test)
X2_train_scaled = scaler.fit_transform(X2_train)

# %%
result2 = []

# %%
for name,model in models.items():
    model.fit(X2_train_scaled,y2_train)
    y2_pred = model.predict(X2_test_scaled)
    Accuracy =accuracy_score(y2_pred , y2_test)
    F1 = f1_score(y2_pred , y2_test)
    Report = classification_report(y2_pred , y2_test)
    result2.append(
        {'model': name,
        'Accuracy': round(Accuracy, 4),
        'F1': round(F1, 4)}
    )

# %%
result2
# Out:
# [{'model': 'Logistic Regression', 'Accuracy': 0.7642, 'F1': 0.75},
#  {'model': 'KNN', 'Accuracy': 0.6943, 'F1': 0.6729},
#  {'model': 'Naive Bayes', 'Accuracy': 0.5677, 'F1': 0.6817},
#  {'model': 'Decision Tree', 'Accuracy': 0.6594, 'F1': 0.6518},
#  {'model': 'SVM', 'Accuracy': 0.7162, 'F1': 0.6829},
#  {'model': 'Random forest', 'Accuracy': 0.7424, 'F1': 0.7177}]

# %%
import joblib

# %%
print(country_encoder.classes_)
print(channel_encoder.classes_)
# Out:
# ['Afghanistan' 'Andorra' 'Argentina' 'Australia' 'Bangladesh' 'Barbados'
#  'Brazil' 'Canada' 'Chile' 'China' 'Colombia' 'Cuba' 'Ecuador' 'Egypt'
#  'El Salvador' 'Finland' 'France' 'Germany' 'India' 'Indonesia' 'Iraq'
#  'Italy' 'Japan' 'Jordan' 'Kuwait' 'Latvia' 'Malaysia' 'Mexico' 'Morocco'
#  'Netherlands' 'Pakistan' 'Peru' 'Philippines' 'Russia' 'Samoa'
#  'Saudi Arabia' 'Singapore' 'South Korea' 'Spain' 'Sweden' 'Switzerland'
#  'Thailand' 'Turkey' 'Ukraine' 'United Arab Emirates' 'United Kingdom'
#  'United States' 'Venezuela' 'Vietnam' nan]
# ['Animals' 'Autos' 'Comedy' 'Education' 'Entertainment' 'Film' 'Games'
#  'Howto' 'Music' 'News' 'Nonprofit' 'People' 'Sports' 'Tech' nan]

# %%
X2 = encode.drop([
    'viral_channel',
    'video_views_for_the_last_30_days',
    'highest_yearly_earnings',
    'subscribers_for_last_30_days'
], axis=1)

# %%
rf = RandomForestClassifier(
    n_estimators=200,
    random_state=42
)

rf.fit(X2_train, y2_train)

joblib.dump(rf, "rf_youtube.pkl")
# Out:
# ['rf_youtube.pkl']

# %%
model = joblib.load("rf_youtube.pkl")

print(model.feature_names_in_)
# Out:
# ['subscribers' 'video views' 'uploads' 'Country' 'channel_type'
#  'created_year' 'Population' 'Urban_population' 'channel_age'
#  'views_per_upload']

# %%
X2_train
# Out:
#      subscribers  video views  uploads  Country  channel_type  created_year  \
# 109     35400000   5556364230        1       49             1        2006.0
# 941     12700000   6001189018      600       46            11        2019.0
# 77      39400000  22302547082        1       49             6        2021.0
# 84      38600000   7339333120   200933       46            10        2009.0
# 280     23600000   7920637200     1251       45             5        2014.0
# ..           ...          ...      ...      ...           ...           ...
# 106     35500000  15657673422     7566       18             8        2013.0
# 270     23800000  10414479943     2425       46             7        2015.0
# 860     13300000   2262690743     3640       18            13        2011.0
# 435     19000000   8281724393     1525       18             4        2017.0
# 102     36300000            0        0       49            14        2013.0
#
# ...

# %%
pred = rf.predict(X2_test)

print(pd.Series(pred).value_counts())
# Out:
# 0    115
# 1    114
# Name: count, dtype: int64

# %%
sample = X2_test.iloc[[0]]

print("Actual:", y2_test.iloc[0])
print("Predicted:", rf.predict(sample)[0])
# Out:
# Actual: 1
# Predicted: 0

# %%
pred = rf.predict(X2_test)

print(pd.Series(pred).value_counts())
# Out:
# 0    115
# 1    114
# Name: count, dtype: int64

# %%
pred = rf.predict(X2_test)

viral_idx = np.where(pred == 1)[0][0]

print(X2_test.iloc[viral_idx])
print("Actual:", y2_test.iloc[viral_idx])
print("Predicted:", pred[viral_idx])
# Out:
# subscribers         1.520000e+07
# video views         8.333388e+09
# uploads             6.540000e+02
# Country             4.200000e+01
# channel_type        4.000000e+00
# created_year        2.014000e+03
# Population          8.342962e+07
# Urban_population    6.309782e+07
# channel_age         1.200000e+01
# views_per_upload    1.274218e+07
# Name: 657, dtype: float64
# Actual: 0
# Predicted: 1

# %%
print(country_encoder.inverse_transform([42]))
print(channel_encoder.inverse_transform([4]))
# Out:
# ['Turkey']
# ['Entertainment']

# %%
joblib.dump(scaler, "scaler.pkl")
joblib.dump(X2.columns.tolist(), "columns.pkl")
joblib.dump(country_encoder, "country_encoder.pkl")
joblib.dump(channel_encoder, "channel_encoder.pkl")
# Out:
# ['channel_encoder.pkl']
